# %% [markdown]
# #Homework 1 - Data Analysis and Regression
# In this assignment your challenge is to do some basic analysis for Airbnb. Provided in hw/data/ there are 2 data files, <a href=../data/bookings.csv>bookings.csv</a> and <a href=../data/listings.csv>listings.csv</a>. The objective is to practice data munging and begin our exploration of regression.

# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns  # for pretty layout of plots
import matplotlib.pyplot as plt

# This enables inline Plots
# %matplotlib inline

# %% [markdown]
# ##Part 1 - Data exploration
# ###First, create 2 data frames: `listings` and `bookings` from their respective data files

# %%
# Let's explore the Datasets
bookings = pd.read_csv('../data/bookings.csv')
listings = pd.read_csv('../data/listings.csv')

# %%
bookings.tail()
# Out:
#       prop_id booking_date
# 6071      408   2011-06-02
# 6072      408   2011-08-22
# 6073      408   2011-07-24
# 6074      408   2011-01-12
# 6075      408   2011-09-08

# %%
listings.tail()
# Out:
#      prop_id        prop_type     neighborhood  price  person_capacity  \
# 403      404  Property type 2  Neighborhood 14    100                1
# 404      405  Property type 2  Neighborhood 13     85                2
# 405      406  Property type 1   Neighborhood 9     70                3
# 406      407  Property type 1  Neighborhood 13    129                2
# 407      408  Property type 1  Neighborhood 14    100                3
#
#      picture_count  description_length  tenure_months
# 403              8                 235              1
# 404             27                1048              1
# 405             18                 153              1
# 406             13                 370              1
# 407             21                 707              1

# %% [markdown]
# ###What is the mean, median and standard deviation of price, person capacity, picture count, description length and tenure of the properties?

# %%
listings.describe()
# Out:
#           prop_id        price  person_capacity  picture_count  \
# count  408.000000   408.000000       408.000000     408.000000
# mean   204.500000   187.806373         2.997549      14.389706
# std    117.923704   353.050858         1.594676      10.477428
# min      1.000000    39.000000         1.000000       1.000000
# 25%    102.750000    90.000000         2.000000       6.000000
# 50%    204.500000   125.000000         2.000000      12.000000
# 75%    306.250000   199.000000         4.000000      20.000000
# max    408.000000  5000.000000        10.000000      71.000000
#
#        description_length  tenure_months
# count          408.000000     408.000000
# mean           309.159314       8.487745
# std            228.021684       5.872088
# min              0.000000       1.000000
# 25%            179.000000       4.000000
# 50%            250.000000       7.000000
# 75%            389.500000      13.000000
# max           1969.000000      30.000000

# %% [markdown]
# ###What what are the mean price, person capacity, picture count, description length and tenure of the properties grouped by property type?

# %%
listings.groupby(['prop_type']).agg(['mean', 'count'])
# Out:
#                     prop_id              price         person_capacity         \
#                        mean  count        mean  count             mean  count
# prop_type
# Property type 1  204.754647    269  237.085502    269         3.516729    269
# Property type 2  206.392593    135   93.288889    135         2.000000    135
# Property type 3  123.500000      4   63.750000      4         1.750000      4
#
#                  picture_count         description_length         \
#                           mean  count                mean  count
# prop_type
# Property type 1      14.695167    269          313.171004    269
# Property type 2      13.948148    135          304.851852    135
# Property type 3       8.750000      4          184.750000      4
#
#                  tenure_months
#                           mean  count
# prop_type
# Property type 1       8.464684    269
# Property type 2       8.377778    135
# Property type 3      13.750000      4

# %% [markdown]
# ###Same, but by property type per neighborhood?

# %%
listings.groupby(['prop_type', 'neighborhood']).agg(['mean', 'count'])
# Out:
#                                     prop_id              price         \
#                                        mean  count        mean  count
# prop_type       neighborhood
# Property type 1 Neighborhood 1   235.000000      1   85.000000      1
#                 Neighborhood 10  307.500000      6  142.500000      6
#                 Neighborhood 11  174.000000     14  159.428571     14
#                 Neighborhood 12  211.307692     39  365.615385     39
#                 Neighborhood 13  190.142857     49  241.897959     49
#                 Neighborhood 14  220.764706     34  164.676471     34
#                 Neighborhood 15  191.560000     25  178.880000     25
#                 Neighborhood 16  233.000000     14  158.928571     14
#                 Neighborhood 17  166.043478     23  189.869565     23
#                 Neighborhood 18  210.000000     22  173.590909     22
#                 Neighborhood 19  253.250000      8  222.375000      8
#                 Neighborhood 2   244.000000      1  250.000000      1
#                 Neighborhood 20  174.111111      9  804.333333      9
#                 Neighborhood 21   79.250000      4  362.500000      4
#                 Neighborhood 22  162.000000      1  225.000000      1
#                 Neighborhood 5   132.500000      2  194.500000      2
#                 Neighborhood 6   291.333333      3  146.000000      3
#                 Neighborhood 7   273.333333      3  161.000000      3
#                 Neighborhood 8   218.250000      4  174.750000      4
#                 Neighborhood 9   265.857143      7  151.142857      7
# Property type 2 Neighborhood 10  327.000000      2  137.500000      2
#                 Neighborhood 11  146.250000      4   78.750000      4
#                 Neighborhood 12  164.263158     19   96.894737     19
#                 Neighborhood 13  199.000000     23   81.130435     23
#                 Neighborhood 14  195.047619     21   83.809524     21
#                 Neighborhood 15  194.666667     15   95.000000     15
#                 Neighborhood 16  251.562500     16   83.625000     16
#                 Neighborhood 17  242.181818     11  102.454545     11
#                 Neighborhood 18  179.333333      9  120.666667      9
#                 Neighborhood 19  256.750000      8   88.875000      8
#                 Neighborhood 20  230.000000      1   60.000000      1
#                 Neighborhood 3   166.000000      1   60.000000      1
#                 Neighborhood 4   118.000000      1   60.000000      1
#                 Neighborhood 7   365.000000      1  100.000000      1
#                 Neighborhood 8   343.000000      1  350.000000      1
#                 Neighborhood 9   165.500000      2  110.000000      2
# Property type 3 Neighborhood 11  178.000000      1   75.000000      1
#                 Neighborhood 14  286.000000      1   75.000000      1
#                 Neighborhood 17   10.000000      1   65.000000      1
#                 Neighborhood 4    20.000000      1   40.000000      1
#
#                                  person_capacity         picture_count         \
#                                             mean  count           mean  count
# prop_type       neighborhood
# Property type 1 Neighborhood 1          2.000000      1      26.000000      1
#                 Neighborhood 10         3.500000      6      13.333333      6
#                 Neighborhood 11         3.214286     14       9.928571     14
#                 Neighborhood 12         3.435897     39      10.820513     39
#                 Neighborhood 13         4.061224     49      15.653061     49
#                 Neighborhood 14         3.205882     34      14.764706     34
#                 Neighborhood 15         3.720000     25      14.320000     25
#                 Neighborhood 16         2.928571     14      21.642857     14
#                 Neighborhood 17         3.521739     23      16.086957     23
#                 Neighborhood 18         2.954545     22      16.090909     22
#                 Neighborhood 19         3.625000      8      11.000000      8
#                 Neighborhood 2          6.000000      1       8.000000      1
#                 Neighborhood 20         2.777778      9       9.444444      9
#                 Neighborhood 21         4.250000      4      49.000000      4
#                 Neighborhood 22         3.000000      1      19.000000      1
#                 Neighborhood 5          2.500000      2       8.500000      2
#                 Neighborhood 6          3.333333      3      12.666667      3
#                 Neighborhood 7          3.666667      3      14.333333      3
#                 Neighborhood 8          5.000000      4      11.000000      4
#                 Neighborhood 9          4.285714      7      13.428571      7
# Property type 2 Neighborhood 10         2.000000      2      20.000000      2
#                 Neighborhood 11         2.000000      4      16.750000      4
#                 Neighborhood 12         1.947368     19      10.473684     19
#                 Neighborhood 13         1.826087     23      16.695652     23
#                 Neighborhood 14         1.857143     21      15.904762     21
#                 Neighborhood 15         2.266667     15      11.733333     15
#                 Neighborhood 16         2.062500     16      15.375000     16
#                 Neighborhood 17         2.000000     11      15.454545     11
#                 Neighborhood 18         2.222222      9      12.333333      9
#                 Neighborhood 19         2.000000      8      15.125000      8
#                 Neighborhood 20         1.000000      1       3.000000      1
#                 Neighborhood 3          2.000000      1       7.000000      1
#                 Neighborhood 4          2.000000      1      10.000000      1
#                 Neighborhood 7          2.000000      1       3.000000      1
#                 Neighborhood 8          4.000000      1       5.000000      1
#                 Neighborhood 9          2.000000      2       3.500000      2
# Property type 3 Neighborhood 11         2.000000      1      15.000000      1
#                 Neighborhood 14         1.000000      1       1.000000      1
#                 Neighborhood 17         2.000000      1      15.000000      1
#                 Neighborhood 4          2.000000      1       4.000000      1
#
#                                  description_length         tenure_months  \
#                                                mean  count           mean
# prop_type       neighborhood
# Property type 1 Neighborhood 1           209.000000      1       6.000000
#                 Neighborhood 10          391.000000      6       3.833333
#                 Neighborhood 11          379.000000     14       9.642857
#                 Neighborhood 12          267.205128     39       7.897436
#                 Neighborhood 13          290.408163     49       9.122449
#                 Neighborhood 14          317.205882     34       8.441176
#                 Neighborhood 15          321.760000     25       9.320000
#                 Neighborhood 16          310.714286     14       7.071429
#                 Neighborhood 17          317.347826     23       9.869565
#                 Neighborhood 18          369.227273     22       8.227273
#                 Neighborhood 19          254.500000      8       6.500000
#                 Neighborhood 2           423.000000      1       6.000000
#                 Neighborhood 20          223.555556      9       9.666667
#                 Neighborhood 21          306.250000      4      14.750000
#                 Neighborhood 22          500.000000      1       9.000000
#                 Neighborhood 5           266.500000      2      11.500000
#                 Neighborhood 6           290.666667      3       4.000000
#                 Neighborhood 7           343.000000      3       5.333333
#                 Neighborhood 8           300.000000      4       6.750000
#                 Neighborhood 9           471.428571      7       5.714286
# Property type 2 Neighborhood 10          126.000000      2       3.500000
#                 Neighborhood 11          161.250000      4      11.250000
#                 Neighborhood 12          244.526316     19       9.842105
#                 Neighborhood 13          418.565217     23       9.739130
#                 Neighborhood 14          348.619048     21       8.714286
#                 Neighborhood 15          301.733333     15       8.200000
#                 Neighborhood 16          246.250000     16       6.687500
#                 Neighborhood 17          308.272727     11       7.181818
#                 Neighborhood 18          297.777778      9       9.222222
#                 Neighborhood 19          383.375000      8       5.500000
#                 Neighborhood 20          101.000000      1       6.000000
#                 Neighborhood 3           264.000000      1       9.000000
#                 Neighborhood 4            95.000000      1      11.000000
#                 Neighborhood 7           148.000000      1       2.000000
#                 Neighborhood 8           223.000000      1       3.000000
#                 Neighborhood 9           114.500000      2       9.000000
# Property type 3 Neighborhood 11          196.000000      1       8.000000
#                 Neighborhood 14          113.000000      1       5.000000
#                 Neighborhood 17          189.000000      1      23.000000
#                 Neighborhood 4           241.000000      1      19.000000
#
#
#                                  count
# prop_type       neighborhood
# Property type 1 Neighborhood 1       1
#                 Neighborhood 10      6
#                 Neighborhood 11     14
#                 Neighborhood 12     39
#                 Neighborhood 13     49
#                 Neighborhood 14     34
#                 Neighborhood 15     25
#                 Neighborhood 16     14
#                 Neighborhood 17     23
#                 Neighborhood 18     22
#                 Neighborhood 19      8
#                 Neighborhood 2       1
#                 Neighborhood 20      9
#                 Neighborhood 21      4
#                 Neighborhood 22      1
#                 Neighborhood 5       2
#                 Neighborhood 6       3
#                 Neighborhood 7       3
#                 Neighborhood 8       4
#                 Neighborhood 9       7
# Property type 2 Neighborhood 10      2
#                 Neighborhood 11      4
#                 Neighborhood 12     19
#                 Neighborhood 13     23
#                 Neighborhood 14     21
#                 Neighborhood 15     15
#                 Neighborhood 16     16
#                 Neighborhood 17     11
#                 Neighborhood 18      9
#                 Neighborhood 19      8
#                 Neighborhood 20      1
#                 Neighborhood 3       1
#                 Neighborhood 4       1
#                 Neighborhood 7       1
#                 Neighborhood 8       1
#                 Neighborhood 9       2
# Property type 3 Neighborhood 11      1
#                 Neighborhood 14      1
#                 Neighborhood 17      1
#                 Neighborhood 4       1

# %% [markdown]
# ###Plot daily bookings:

# %%
# Plot daily bookings
#grid_plot = sns.FacetGrid(bookings, row='booking_date', col='prop_id')
#grid_plot.map(sns.regplot, 'booking_date', color='.3', fit_reg=False, x_jitter=.1)


#prop_id	booking_date 

#ax = sns.boxplot(bookings.age)
#ax.set_title('Age Distribution by class')

bookings.groupby(['booking_date']).agg(['count']).plot(kind='scatter')

#auto_mpg.groupby('cylinders')['mpg'].count().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-190b20eb0d66> in <module>()
#       9 #ax.set_title('Age Distribution by class')
#      10
# ---> 11 bookings.groupby(['booking_date']).agg(['count']).plot(kind='scatter')
#      12
#      13 #auto_mpg.groupby('cylinders')['mpg'].count().plot(kind='bar')
#
# /Users/johnfohr/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logx, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    2105                          figsize=figsize, logx=logx, logy=logy,
#    2106                          sort_columns=sort_columns, secondary_y=secondary_y,
# -> 2107                          **kwds)
#    2108     elif kind in _series_kinds:
#    2109         if y is None and subplots is False:
#
# /Users/johnfohr/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __init__(self, data, x, y, **kwargs)
#    1382         self.kwds.setdefault('c', self.plt.rcParams['patch.facecolor'])
#    1383         if x is None or y is None:
# -> 1384             raise ValueError( 'scatter requires and x and y column')
#    1385         if com.is_integer(x) and not self.data.columns.holds_integer():
#    1386             x = self.data.columns[x]
#
# ValueError: scatter requires and x and y column

# %%
fig, ax = plt.subplots(1, 1)

ax.scatter(bookings, prop_id)
ax.set_xlabel('Neighborhood')
ax.set_ylabel('Bookings')

# Draw the ideal line
ax.plot(target, target, 'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0574742825e2> in <module>()
#       1 fig, ax = plt.subplots(1, 1)
#       2
# ----> 3 ax.scatter(bookings, prop_id)
#       4 ax.set_xlabel('Neighborhood')
#       5 ax.set_ylabel('Bookings')
#
# NameError: name 'prop_id' is not defined

# %% [markdown]
# ###Plot the daily bookings per neighborhood (provide a legend)

# %% [markdown]
# ##Part 2 - Develop a data set

# %% [markdown]
# ###Add the columns `number_of_bookings` and `booking_rate` (number_of_bookings/tenure_months) to your `listings` data frame

# %% [markdown]
# ###We only want to analyze well established properties, so let's filter out any properties that have a tenure less than 10 months

# %% [markdown]
# ###`prop_type` and `neighborhood` are categorical variables, use `get_dummies()` (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.reshape.get_dummies.html) to transform this column of categorical data to many columns of boolean values (after applying this function correctly there should be 1 column for every prop_type and 1 column for every neighborhood category.

# %% [markdown]
# ###create test and training sets for your regressors and predictors
# predictor (y) is `booking_rate`, regressors (X) are everything else, except `prop_id`,`booking_rate`,`prop_type`,`neighborhood` and `number_of_bookings`<br>
# http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.train_test_split.html<br>
# http://pandas.pydata.org/pandas-docs/stable/basics.html#dropping-labels-from-an-axis

# %%
from sklearn.cross_validation import train_test_split

# %% [markdown]
# ##Part 3 - Model `booking_rate`

# %% [markdown]
# ###Create a linear regression model of your listings

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# ###fit your model with your test sets

# %% [markdown]
# ###report the score
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score

# %% [markdown]
# ###Interpret the results of the above model:
# * What does the `score` method do?
# * What does this tell us about our model?

# %% [markdown]
# ...type here...

# %% [markdown]
# ##Optional - Iterate
# Create an alternative predictor (e.g. monthly revenue) and use the same modeling pattern in Part 3 to
